# %% [markdown]
# # step 1 : imports

# %%
import pandas as pd
import plotly.express as px
import sqlalchemy
import numpy as np

# %%
df = pd.read_csv(r'nbastats2018-2019.csv')
df.head()
# Out:
#            Name  Height  Weight                   Team  Age    Salary  Points  \
# 0  Alex Abrines      78     200  Oklahoma City Thunder   25   5455236     5.3
# 1    Quincy Acy      79     240           Phoenix Suns   28    213949     1.7
# 2  Jaylen Adams      74     190          Atlanta Hawks   22    236854     3.2
# 3  Steven Adams      84     265  Oklahoma City Thunder   25  24157304    13.9
# 4   Bam Adebayo      82     255             Miami Heat   21   2955840     8.9
#
#    Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS   WS48   USG  \
# 0     0.2     0.5      0.6  ...  19.0  31   6.3  0.1  0.6  0.6  0.053  12.2
# 1     0.4     0.1      0.8  ...  12.3  10   2.9 -0.1  0.0 -0.1 -0.022   9.2
# 2     0.1     0.4      1.9  ...  12.6  34   7.6 -0.1  0.2  0.1  0.011  13.5
# 3     1.0     1.5      1.6  ...  33.4  80  18.5  5.1  4.0  9.1  0.163  16.4
# 4     0.8     0.9      2.2  ...  23.3  82  17.9  3.4  3.4  6.8  0.171  15.8
#
#    BPM  VORP
# 0 -3.4  -0.2
# 1 -5.9  -0.1
# 2 -4.4  -0.3
# 3  2.7   3.2
# 4  3.0   2.4
#
# [5 rows x 27 columns]

# %% [markdown]
# # step 2: clean data

# %% [markdown]
# ## fix up column names

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(' ','_')

# %% [markdown]
# # step 3 : exploratory data analysis

# %%
df.describe()
df.info()
df.shape
df.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      521 non-null    object
#  1   height    521 non-null    int64
#  2   weight    521 non-null    int64
#  3   team      470 non-null    object
#  4   age       521 non-null    int64
#  5   salary    521 non-null    object
#  6   points    521 non-null    float64
#  7   blocks    521 non-null    float64
#  8   steals    521 non-null    float64
#  9   assists   521 non-null    float64
#  10  rebounds  521 non-null    float64
#  11  ft%       499 non-null    float64
#  12  fta       521 non-null    float64
#  13  fg3%      489 non-null    float64
#  14  fg3a      521 non-null    float64
#  15  fg%       519 non-null    float64
#  16  fga       521 non-null    float64
#  17  mp        521 non-null    float64
#  18  g         521 non-null    int64
#  19  per       521 non-null    float64
#  20  ows       521 non-null    float64
#  21  dws       521 non-null    float64
#  22  ws        521 non-null    float64
#  23  ws48      521 non-null    float64
#  24  usg       521 non-null    float64
#  25  bpm       521 non-null    float64
#  26  vorp      521 non-null    float64
# dtypes: float64(20), int64(4), object(3)
# memory usage: 110.0+ KB
# name                   height  weight  team                    age  salary    points  blocks  steals  assists  rebounds  ft%    fta  fg3%   fg3a  fg%    fga   mp    g   per   ows   dws  ws     ws48    usg   bpm    vorp
# Aaron Gordon           81      220     Orlando Magic           23   21590909  16.0    0.7     0.7     3.7      7.4       0.731  3.2  0.349  4.4   0.449  13.4  33.8  78  15.1   1.8  3.3   5.1    0.093  21.8   1.0    2.0    1
# Mario Hezonja          80      225     New York Knicks         23   6500000   8.8     0.1     1.0     1.5      4.1       0.763  2.0  0.276  2.6   0.412  8.0   20.8  58  10.8  -1.1  1.1  -0.1   -0.003  21.3  -4.0   -0.6    1
# Meyers Leonard         85      255     Portland Trail Blazers  26   10595506  5.9     0.1     0.2     1.2      3.8       0.843  0.8  0.450  1.8   0.545  4.0   14.4  61  15.8   2.1  0.9   3.0    0.164  14.8   1.4    0.8    1
# Melvin Frazier         78      200     Orlando Magic           22   1050000   1.5     0.0     0.1     0.1      0.5       0.250  0.4  0.000  0.6   0.333  2.1   4.4   10  1.2   -0.2  0.0  -0.1   -0.133  23.5  -12.9  -0.1    1
# Maxi Kleber            83      240     Dallas Mavericks        27   1378242   6.8     1.1     0.5     1.0      4.6       0.784  1.0  0.353  3.1   0.453  5.4   21.2  71  13.1   1.6  1.8   3.5    0.111  13.5   1.5    1.3    1
#                                                                                                                                                                                                                              ..
# Glenn Robinson III     78      222     Detroit Pistons         25   4075000   4.2     0.2     0.3     0.4      1.5       0.800  0.9  0.290  1.3   0.420  3.7   13.0  47  8.7    0.1  0.6   0.7    0.054  15.0  -4.2   -0.3    1
# Giannis Antetokounmpo  83      242     Milwaukee Bucks         24   24157304  27.7    1.5     1.3     5.9      12.5      0.729  9.5  0.256  2.8   0.578  17.3  32.8  72  30.9   8.9  5.5   14.4   0.292  32.3   10.8   7.6    1
# Gerald Green           79      205     Houston Rockets         33   2393887   9.2     0.4     0.5     0.5      2.5       0.838  0.9  0.354  6.0   0.400  7.9   20.2  73  11.4   0.9  1.0   1.9    0.061  19.5  -3.4   -0.5    1
# Georges Niang          80      230     Utah Jazz               25   1512601   4.0     0.1     0.2     0.6      1.5       0.833  0.4  0.410  1.8   0.475  3.1   8.7   59  13.0   0.7  0.7   1.3    0.123  17.8  -1.1    0.1    1
# Zhaire Smith           76      199     Philadelphia 76ers      19   2611800   6.7     0.3     0.3     1.7      2.2       0.750  1.3  0.375  2.7   0.412  5.7   18.5  6   9.5    0.0  0.1   0.1    0.048  16.4  -4.0   -0.1    1
# Name: count, Length: 434, dtype: int64

# %%
# clean missing team and missing salary
df['team'] = df['team'].fillna('Unassigned')

# %%
df['salary'] = df['salary'].replace('-', '0')
df['salary'] = df['salary'].astype(int)

# %%
for col in df.columns:
    threshold = 1
    if df[col].dtype != 'O':
        if df[col].isna().sum() >= threshold:
            df[col] = df[col].fillna(df[col].mean())
# fill na with mean if there are null values in column

# %%
for col in df.columns:
    if df[col].dtype != 'O':
        display(px.histogram(df,col))

# %%
for col in df.columns:
    if df[col].dtype != 'O':
        display(px.bar(df,'team', col, 'team'))

# %% [markdown]
# # connecting to mysql

# %% [markdown]
# mysql connection formula:
# mysql+mysqldb://username:password@port/db

# %%
con_str = 'mysql+mysqldb://ct_python:1ceT4me8*@localhost/new_schema'

my_con = sqlalchemy.create_engine(con_str)

# %%
df.to_sql('nba_player_stats', con=my_con, index=False, if_exists='replace')
# Out:
# 521

# %%
df = pd.read_sql('SELECT * FROM nba_player_stats', con = my_con)

# %%
df.to_csv('nbastats2018-2019_clean.csv', index=False)

# %% [markdown]
# # pt 2 - acnh

# %%
df_3 = pd.read_csv(r'acnh/accessories.csv')

# %%
df_3.head()
# Out:
#               Name Variation DIY  Buy  Sell Color 1   Color 2 Size  \
# 0       3D glasses     White  No  490   122   White  Colorful  1x1
# 1       3D glasses     Black  No  490   122   Black  Colorful  1x1
# 2          bandage     Beige  No  140    35   Beige     White  1x1
# 3             beak    Yellow  No  490   122  Yellow    Yellow  1x1
# 4  birthday shades    Yellow  No  NFS   620  Yellow       Red  1x1
#
#    Miles Price        Source  ... Mannequin Piece Version     Style  \
# 0          NaN  Able Sisters  ...              No   1.0.0    Active
# 1          NaN  Able Sisters  ...              No   1.0.0    Active
# 2          NaN  Able Sisters  ...             Yes   1.0.0    Active
# 3          NaN  Able Sisters  ...             Yes   1.0.0      Cute
# 4          NaN      Birthday  ...              No   1.0.0  Gorgeous
#
#                     Label Themes                         Type  \
# 0                          party                 AccessoryEye
# 1                          party                 AccessoryEye
# 2       outdoorsy; comfy; sporty               AccessoryMouth
# 3  fairy tale; party; theatrical  AccessoryMouthInvisibleNose
# 4                          party                 AccessoryEye
#
#   Villager Equippable       Catalog                   Filename Internal ID  \
# 0                 Yes      For sale      AccessoryGlassThreed0        4463
# 1                 Yes      For sale      AccessoryGlassThreed1       11020
# 2                  No      For sale  AccessoryMouthBandageSkin        4677
# 3                  No      For sale   AccessoryMouthBeakYellow        3549
# 4                 Yes  Not for sale    AccessoryGlassBirthday0        4510
#
#      Unique Entry ID
# 0  FNxEraBTeWRiCvtFu
# 1  mM9SXPCcGPfPJAmtm
# 2  2qFT5iPkk8bREvpkj
# 3  T5CpsJi4xBSachNL5
# 4  S6CiB9ZvzBTMhEnDz
#
# [5 rows x 22 columns]

# %%
df_3.columns = df_3.columns.str.lower().str.strip().str.replace(' ','_')

# %%
df_3.columns
# Out:
# Index(['name', 'variation', 'diy', 'buy', 'sell', 'color_1', 'color_2', 'size',
#        'miles_price', 'source', 'source_notes', 'seasonal_availability',
#        'mannequin_piece', 'version', 'style', 'label_themes', 'type',
#        'villager_equippable', 'catalog', 'filename', 'internal_id',
#        'unique_entry_id'],
#       dtype='object')

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   222 non-null    object
#  1   variation              222 non-null    object
#  2   diy                    222 non-null    object
#  3   buy                    222 non-null    object
#  4   sell                   222 non-null    int64
#  5   color_1                222 non-null    object
#  6   color_2                222 non-null    object
#  7   size                   222 non-null    object
#  8   miles_price            1 non-null      float64
#  9   source                 222 non-null    object
#  10  source_notes           206 non-null    object
#  11  seasonal_availability  222 non-null    object
#  12  mannequin_piece        222 non-null    object
#  13  version                222 non-null    object
#  14  style                  222 non-null    object
#  15  label_themes           222 non-null    object
#  16  type                   222 non-null    object
#  17  villager_equippable    222 non-null    object
#  18  catalog                222 non-null    object
#  19  filename               222 non-null    object
#  20  internal_id            222 non-null    int64
#  21  unique_entry_id        222 non-null    object
# dtypes: float64(1), int64(2), object(19)
# memory usage: 38.3+ KB

# %%
df_3.groupby('buy').size()
# replace NFS with negative number instead of 0 (or 9999)

df_3['buy'].replace('NFS', '-1', inplace=True)

# %%
df_3['buy'] = df_3['buy'].astype('int')
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   222 non-null    object
#  1   variation              222 non-null    object
#  2   diy                    222 non-null    object
#  3   buy                    222 non-null    int32
#  4   sell                   222 non-null    int64
#  5   color_1                222 non-null    object
#  6   color_2                222 non-null    object
#  7   size                   222 non-null    object
#  8   miles_price            1 non-null      float64
#  9   source                 222 non-null    object
#  10  source_notes           206 non-null    object
#  11  seasonal_availability  222 non-null    object
#  12  mannequin_piece        222 non-null    object
#  13  version                222 non-null    object
#  14  style                  222 non-null    object
#  15  label_themes           222 non-null    object
#  16  type                   222 non-null    object
#  17  villager_equippable    222 non-null    object
#  18  catalog                222 non-null    object
#  19  filename               222 non-null    object
#  20  internal_id            222 non-null    int64
#  21  unique_entry_id        222 non-null    object
# dtypes: float64(1), int32(1), int64(2), object(18)
# memory usage: 37.4+ KB

# %%
df_3[df_3['miles_price'] == 400.0]
# Out:
#                    name variation diy  buy  sell color_1 color_2 size  \
# 120  Nook Inc. eye mask     Green  No   -1  2000   Green   White  1x1
#
#      miles_price           source  ... mannequin_piece version   style  \
# 120        400.0  Nook Miles Shop  ...              No   1.0.0  Simple
#
#     label_themes          type villager_equippable       catalog  \
# 120        comfy  AccessoryEye                 Yes  Not for sale
#
#                 filename internal_id    unique_entry_id
# 120  AccessoryGlassNook0        9654  n8j5gx4zjuK7tkYKq
#
# [1 rows x 22 columns]

# %%
df_3['label_themes'] = df_3['label_themes'].str.split(';')
df_3.head()

#drop miles_price
# fill source with
# Out:
#               name variation diy  buy  sell color_1   color_2 size  \
# 0       3D glasses     White  No  490   122   White  Colorful  1x1
# 1       3D glasses     Black  No  490   122   Black  Colorful  1x1
# 2          bandage     Beige  No  140    35   Beige     White  1x1
# 3             beak    Yellow  No  490   122  Yellow    Yellow  1x1
# 4  birthday shades    Yellow  No   -1   620  Yellow       Red  1x1
#
#    miles_price        source  ... mannequin_piece version     style  \
# 0          NaN  Able Sisters  ...              No   1.0.0    Active
# 1          NaN  Able Sisters  ...              No   1.0.0    Active
# 2          NaN  Able Sisters  ...             Yes   1.0.0    Active
# 3          NaN  Able Sisters  ...             Yes   1.0.0      Cute
# 4          NaN      Birthday  ...              No   1.0.0  Gorgeous
#
#                         label_themes                         type  \
# 0                            [party]                 AccessoryEye
# 1                            [party]                 AccessoryEye
# 2       [outdoorsy,  comfy,  sporty]               AccessoryMouth
# 3  [fairy tale,  party,  theatrical]  AccessoryMouthInvisibleNose
# 4                            [party]                 AccessoryEye
#
#   villager_equippable       catalog                   filename internal_id  \
# 0                 Yes      For sale      AccessoryGlassThreed0        4463
# 1                 Yes      For sale      AccessoryGlassThreed1       11020
# 2                  No      For sale  AccessoryMouthBandageSkin        4677
# 3                  No      For sale   AccessoryMouthBeakYellow        3549
# 4                 Yes  Not for sale    AccessoryGlassBirthday0        4510
#
#      unique_entry_id
# 0  FNxEraBTeWRiCvtFu
# 1  mM9SXPCcGPfPJAmtm
# 2  2qFT5iPkk8bREvpkj
# 3  T5CpsJi4xBSachNL5
# 4  S6CiB9ZvzBTMhEnDz
#
# [5 rows x 22 columns]

# %%
threshold = int(len(df_3)*.3)

threshold
# Out:
# 66

# %%
for column in df_3.columns:
    print(column)
    
df_3['color_1'].nunique()
# Out:
# name
# variation
# diy
# buy
# sell
# color_1
# color_2
# size
# miles_price
# source
# source_notes
# seasonal_availability
# mannequin_piece
# version
# style
# label_themes
# type
# villager_equippable
# catalog
# filename
# internal_id
# unique_entry_id
# 14

# %%
col_to_drop = []
for column in df_3.columns:
    if df_3[column].nunique() >= 10:
        col_to_drop.append(column)

col_to_drop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# h:\Dropbox\CodingTemple\CT_Coursework\week_6\week_6_day2.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/h%3A/Dropbox/CodingTemple/CT_Coursework/week_6/week_6_day2.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> col_to_drop = []
#       <a href='vscode-notebook-cell:/h%3A/Dropbox/CodingTemple/CT_Coursework/week_6/week_6_day2.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> for column in df_3.columns:
# ----> <a href='vscode-notebook-cell:/h%3A/Dropbox/CodingTemple/CT_Coursework/week_6/week_6_day2.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a>     if df_3[column].nunique() >= 10:
#       <a href='vscode-notebook-cell:/h%3A/Dropbox/CodingTemple/CT_Coursework/week_6/week_6_day2.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a>         col_to_drop.append(column)
#       <a href='vscode-notebook-cell:/h%3A/Dropbox/CodingTemple/CT_Coursework/week_6/week_6_day2.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a> col_to_drop
#
# File c:\Users\Annie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:1063, in IndexOpsMixin.nunique(self, dropna)
#    1028 @final
#    1029 def nunique(self, dropna: bool = True) -> int:
#    1030     """
#    1031     Return number of unique elements in the object.
#    1032
#    (...)
#    1061     4
#    1062     """
# -> 1063     uniqs = self.unique()
#    1064     if dropna:
#    1065         uniqs = remove_na_arraylike(uniqs)
#
# File c:\Users\Annie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:2287, in Series.unique(self)
#    2224 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2225     """
#    2226     Return unique values of Series object.
#    2227
#    (...)
#    2285     Categories (3, object): ['a' < 'b' < 'c']
#    2286     """
# -> 2287     return super().unique()
#
# File c:\Users\Annie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File c:\Users\Annie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File c:\Users\Annie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# File pandas\_libs\hashtable_class_helper.pxi:7247, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas\_libs\hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
